# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.3 MB/s eta 0:00:00
# ...

# %%
# !wget https://github.com/luiz826/rubber-duck/raw/refs/heads/master/data/rubber-duck-detection.zip
# Out:
# --2025-08-27 00:01:42--  https://github.com/luiz826/rubber-duck/raw/refs/heads/master/data/rubber-duck-detection.zip
# Resolving github.com (github.com)... 140.82.116.4
# Connecting to github.com (github.com)|140.82.116.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/luiz826/rubber-duck/refs/heads/master/data/rubber-duck-detection.zip [following]
# --2025-08-27 00:01:43--  https://raw.githubusercontent.com/luiz826/rubber-duck/refs/heads/master/data/rubber-duck-detection.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9212406 (8.8M) [application/zip]
# Saving to: ‘rubber-duck-detection.zip’
#
# rubber-duck-detecti 100%[===================>]   8.79M  17.7MB/s    in 0.5s
#
# ...

# %%
# !unzip rubber-duck-detection.zip
# Out:
# Archive:  rubber-duck-detection.zip
#   inflating: README.dataset.txt
#   inflating: README.roboflow.txt
#   inflating: data.yaml
#    creating: train/
#    creating: train/images/
#  extracting: train/images/image_102_jpg.rf.051f1c81d15986a439ae58bb7db29c86.jpg
#  extracting: train/images/image_102_jpg.rf.55726de298ab6712561b6811ae961998.jpg
#  extracting: train/images/image_105_jpg.rf.3732a4ba5340df265b140c0caecb8a62.jpg
#  extracting: train/images/image_105_jpg.rf.4ca512c9ead7360b59553c821bced3ae.jpg
#  extracting: train/images/image_105_jpg.rf.c5671e7fd77afd12e169bf80c3bff73e.jpg
#  extracting: train/images/image_10_jpg.rf.365131b1a1765a0b83769258d5a8a495.jpg
#  extracting: train/images/image_10_jpg.rf.7e742766acf94cdee46418acf8abcd97.jpg
#  extracting: train/images/image_10_jpg.rf.9cb90927b7b08f9a921fd229b19d2c69.jpg
#  extracting: train/images/image_113_jpg.rf.05ec1113cf61ff2984e8edfdf4e58d63.jpg
#  extracting: train/images/image_113_jpg.rf.594e4cc345a65ab974233df592679e61.jpg
# ...

# %%
from ultralytics import YOLO

# Load a pretrained YOLO11n model
model = YOLO("yolo11n.pt")


train_results = model.train(
    data="data.yaml",  # Path to dataset configuration file
    epochs=50,  # Number of training epochs
    imgsz=640,  # Image size for training
    device="cuda",  # Device to run on (e.g., 'cpu', 0, [0,1,2,3])
)

# Evaluate the model's performance on the validation set
metrics = model.val()
# Out:
# Ultralytics 8.3.186 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...
